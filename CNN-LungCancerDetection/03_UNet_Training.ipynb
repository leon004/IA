# %%
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
trainX = np.load("/content/gdrive/MyDrive/archive/ProcessedData/trainX.npy").astype(np.float32)
trainY = np.load("/content/gdrive/MyDrive/archive/ProcessedData/trainY.npy").astype(np.float32)
testX = np.load("/content/gdrive/MyDrive/archive/ProcessedData/testX.npy").astype(np.float32)
testY = np.load("/content/gdrive/MyDrive/archive/ProcessedData/testY.npy").astype(np.float32)

# %%
trainX.shape
# Out:
# (241, 512, 512)

# %%
trainX = (trainX-127.0)/127.0
testX = (testX-127.0)/127.0
trainY = (trainY>127).astype(np.float32)
testY = (testY>127).astype(np.float32)

# %%
print(trainX.dtype)
print(trainY.dtype)
print(testX.dtype)
print(testY.dtype)
# Out:
# float32
# float32
# float32
# float32

# %%
trainX = np.reshape(trainX, (len(trainX), 512, 512, 1))
trainY = np.reshape(trainY, (len(trainY), 512, 512, 1))
testX = np.reshape(testX, (len(testX), 512, 512, 1))
testY = np.reshape(testY, (len(testY), 512, 512, 1))

print("trainX:",trainX.shape)
print("trainY:",trainY.shape)
print("testX:",testX.shape)
print("testY:",testY.shape)
# Out:
# trainX: (241, 512, 512, 1)
# trainY: (241, 512, 512, 1)
# testX: (61, 512, 512, 1)
# testY: (61, 512, 512, 1)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
def unet(input_size=(512,512,1)):
    inputs = Input(input_size)
    K.set_image_data_format('channels_last')

    #Encoder
    conv1 = Conv2D(32, (3,3), activation="relu", padding="same")(inputs)
    conv1 = Conv2D(32, (3,3), activation="relu", padding="same")(conv1)
    pool1 = MaxPooling2D(pool_size=(2,2))(conv1)

    conv2 = Conv2D(64, (3,3), activation="relu", padding="same")(pool1)
    conv2 = Conv2D(64, (3,3), activation="relu", padding="same")(conv2)
    pool2 = MaxPooling2D(pool_size=(2,2))(conv2)

    conv3 = Conv2D(128, (3,3), activation="relu", padding="same")(pool2)
    conv3 = Conv2D(128, (3,3), activation="relu", padding="same")(conv3)
    pool3 = MaxPooling2D(pool_size=(2,2))(conv3)

    conv4 = Conv2D(256, (3,3), activation="relu", padding="same")(pool3)
    conv4 = Conv2D(256, (3,3), activation="relu", padding="same")(conv4)
    pool4 = MaxPooling2D(pool_size=(2,2))(conv4)

    #BottleNeck
    conv5 = Conv2D(512, (3,3), activation="relu", padding="same")(pool4)
    conv5 = Conv2D(512, (3,3), activation="relu", padding="same")(conv5)

    #Decoder
    up6 = concatenate([Conv2DTranspose(256, kernel_size=(2,2), strides=(2,2), padding="same")(conv5), conv4], axis=-1)
    conv6 = Conv2D(256, (3,3), activation="relu", padding="same")(up6)
    conv6 = Conv2D(256, (3,3), activation="relu", padding="same")(conv6)

    up7 = concatenate([Conv2DTranspose(128, kernel_size=(2,2), strides=(2,2), padding="same")(conv6), conv3], axis=-1)
    conv7 = Conv2D(128, (3,3), activation="relu", padding="same")(up7)
    conv7 = Conv2D(128, (3,3), activation="relu", padding="same")(conv7)

    up8 = concatenate([Conv2DTranspose(64, kernel_size=(2,2), strides=(2,2), padding="same")(conv7), conv2], axis=-1)
    conv8 = Conv2D(64, (3,3), activation="relu", padding="same")(up8)
    conv8 = Conv2D(64, (3,3), activation="relu", padding="same")(conv8)

    up9 = concatenate([Conv2DTranspose(32, kernel_size=(2,2), strides=(2,2), padding="same")(conv8), conv1], axis=-1)
    conv9 = Conv2D(32, (3,3), activation="relu", padding="same")(up9)
    conv9 = Conv2D(32, (3,3), activation="relu", padding="same")(conv9)

    conv10 = Conv2D(1, (1,1), activation="sigmoid")(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
weight_path="checkpoint-{epoch:03d}-{val_dice_coef:.3f}.hdf5"

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.7,
                                   patience=2,
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=18)

CALLBACKS = [checkpoint, early, reduceLROnPlat]

# %%
model = unet(input_size=(512, 512, 1))
model.compile(optimizer=Adam(learning_rate=2e-4),
              loss=[dice_coef_loss],
              metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 512, 512, 32)         320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 512, 512, 32)         9248      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 256, 256, 32)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 64)         18496     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 64)         36928     ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 64)         0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 128)        73856     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 128)        147584    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 128)          0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 256)          295168    ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 256)          590080    ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 256)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 512)          1180160   ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 512)          2359808   ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 64, 64, 256)          524544    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 64, 64, 512)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 256)          1179904   ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 128, 128, 128)        131200    ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 128, 128, 256)        0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 256, 256, 64)         32832     ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 512, 512, 32)         8224      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 512, 512, 64)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 512, 512, 32)         18464     ['concatenate_3[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 512, 512, 32)         9248      ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 512, 512, 1)          33        ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7759521 (29.60 MB)
# Trainable params: 7759521 (29.60 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
history = model.fit(x = trainX,
                    y = trainY,
                    batch_size = 16,
                    epochs = 100,
                    validation_data =(testX,testY),
                    callbacks=CALLBACKS
                  )
# Out:
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7405 - dice_coef: 0.7481 - binary_accuracy: 0.9996
# Epoch 1: val_loss improved from -0.72850 to -0.73775, saving model to checkpoint-001-0.740.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7405 - dice_coef: 0.7481 - binary_accuracy: 0.9996 - val_loss: -0.7378 - val_dice_coef: 0.7399 - val_binary_accuracy: 0.9997 - lr: 6.8600e-05
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7513 - dice_coef: 0.7085 - binary_accuracy: 0.9997
# Epoch 2: val_loss did not improve from -0.73775
# 16/16 [==============================] - 17s 1s/step - loss: -0.7513 - dice_coef: 0.7085 - binary_accuracy: 0.9997 - val_loss: -0.7305 - val_dice_coef: 0.7327 - val_binary_accuracy: 0.9997 - lr: 6.8600e-05
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7579 - dice_coef: 0.7696 - binary_accuracy: 0.9997
# Epoch 3: val_loss improved from -0.73775 to -0.74135, saving model to checkpoint-003-0.743.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7579 - dice_coef: 0.7696 - binary_accuracy: 0.9997 - val_loss: -0.7413 - val_dice_coef: 0.7434 - val_binary_accuracy: 0.9997 - lr: 6.8600e-05
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7639 - dice_coef: 0.7403 - binary_accuracy: 0.9997
# Epoch 4: val_loss did not improve from -0.74135
# 16/16 [==============================] - 17s 1s/step - loss: -0.7639 - dice_coef: 0.7403 - binary_accuracy: 0.9997 - val_loss: -0.7301 - val_dice_coef: 0.7321 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7532 - dice_coef: 0.7144 - binary_accuracy: 0.9997
# Epoch 5: val_loss improved from -0.74135 to -0.74460, saving model to checkpoint-005-0.747.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7532 - dice_coef: 0.7144 - binary_accuracy: 0.9997 - val_loss: -0.7446 - val_dice_coef: 0.7470 - val_binary_accuracy: 0.9997 - lr: 6.8600e-05
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7736 - dice_coef: 0.7285 - binary_accuracy: 0.9997
# Epoch 6: val_loss improved from -0.74460 to -0.74912, saving model to checkpoint-006-0.751.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7736 - dice_coef: 0.7285 - binary_accuracy: 0.9997 - val_loss: -0.7491 - val_dice_coef: 0.7515 - val_binary_accuracy: 0.9997 - lr: 6.8600e-05
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7075 - dice_coef: 0.6666 - binary_accuracy: 0.9996
# Epoch 7: val_loss did not improve from -0.74912
# 16/16 [==============================] - 17s 1s/step - loss: -0.7075 - dice_coef: 0.6666 - binary_accuracy: 0.9996 - val_loss: -0.6575 - val_dice_coef: 0.6620 - val_binary_accuracy: 0.9996 - lr: 6.8600e-05
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7279 - dice_coef: 0.6854 - binary_accuracy: 0.9996
# Epoch 8: val_loss did not improve from -0.74912
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.801999384653754e-05.
# 16/16 [==============================] - 17s 1s/step - loss: -0.7279 - dice_coef: 0.6854 - binary_accuracy: 0.9996 - val_loss: -0.7300 - val_dice_coef: 0.7322 - val_binary_accuracy: 0.9997 - lr: 6.8600e-05
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7401 - dice_coef: 0.7509 - binary_accuracy: 0.9997
# Epoch 9: val_loss did not improve from -0.74912
# 16/16 [==============================] - 17s 1s/step - loss: -0.7401 - dice_coef: 0.7509 - binary_accuracy: 0.9997 - val_loss: -0.7485 - val_dice_coef: 0.7502 - val_binary_accuracy: 0.9997 - lr: 4.8020e-05
# Epoch 10/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7491 - dice_coef: 0.7541 - binary_accuracy: 0.9997
# Epoch 10: val_loss did not improve from -0.74912
# 16/16 [==============================] - 17s 1s/step - loss: -0.7491 - dice_coef: 0.7541 - binary_accuracy: 0.9997 - val_loss: -0.7454 - val_dice_coef: 0.7471 - val_binary_accuracy: 0.9997 - lr: 4.8020e-05
# Epoch 11/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7748 - dice_coef: 0.7854 - binary_accuracy: 0.9997
# Epoch 11: val_loss did not improve from -0.74912
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 3.3613994673942216e-05.
# 16/16 [==============================] - 17s 1s/step - loss: -0.7748 - dice_coef: 0.7854 - binary_accuracy: 0.9997 - val_loss: -0.7455 - val_dice_coef: 0.7477 - val_binary_accuracy: 0.9997 - lr: 4.8020e-05
# Epoch 12/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7713 - dice_coef: 0.7506 - binary_accuracy: 0.9997
# Epoch 12: val_loss did not improve from -0.74912
# 16/16 [==============================] - 17s 1s/step - loss: -0.7713 - dice_coef: 0.7506 - binary_accuracy: 0.9997 - val_loss: -0.7463 - val_dice_coef: 0.7487 - val_binary_accuracy: 0.9997 - lr: 3.3614e-05
# Epoch 13/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7803 - dice_coef: 0.7751 - binary_accuracy: 0.9997
# Epoch 13: val_loss improved from -0.74912 to -0.75301, saving model to checkpoint-013-0.755.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7803 - dice_coef: 0.7751 - binary_accuracy: 0.9997 - val_loss: -0.7530 - val_dice_coef: 0.7553 - val_binary_accuracy: 0.9997 - lr: 3.3614e-05
# Epoch 14/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7801 - dice_coef: 0.7347 - binary_accuracy: 0.9997
# Epoch 14: val_loss improved from -0.75301 to -0.76306, saving model to checkpoint-014-0.765.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7801 - dice_coef: 0.7347 - binary_accuracy: 0.9997 - val_loss: -0.7631 - val_dice_coef: 0.7649 - val_binary_accuracy: 0.9997 - lr: 3.3614e-05
# Epoch 15/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7801 - dice_coef: 0.7917 - binary_accuracy: 0.9997
# Epoch 15: val_loss did not improve from -0.76306
# 16/16 [==============================] - 17s 1s/step - loss: -0.7801 - dice_coef: 0.7917 - binary_accuracy: 0.9997 - val_loss: -0.7599 - val_dice_coef: 0.7621 - val_binary_accuracy: 0.9997 - lr: 3.3614e-05
# Epoch 16/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7902 - dice_coef: 0.7909 - binary_accuracy: 0.9997
# Epoch 16: val_loss did not improve from -0.76306
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.3529794998466968e-05.
# 16/16 [==============================] - 17s 1s/step - loss: -0.7902 - dice_coef: 0.7909 - binary_accuracy: 0.9997 - val_loss: -0.7550 - val_dice_coef: 0.7573 - val_binary_accuracy: 0.9997 - lr: 3.3614e-05
# Epoch 17/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7889 - dice_coef: 0.7719 - binary_accuracy: 0.9997
# Epoch 17: val_loss did not improve from -0.76306
# 16/16 [==============================] - 17s 1s/step - loss: -0.7889 - dice_coef: 0.7719 - binary_accuracy: 0.9997 - val_loss: -0.7606 - val_dice_coef: 0.7628 - val_binary_accuracy: 0.9997 - lr: 2.3530e-05
# Epoch 18/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7969 - dice_coef: 0.7982 - binary_accuracy: 0.9997
# Epoch 18: val_loss did not improve from -0.76306
# 16/16 [==============================] - 17s 1s/step - loss: -0.7969 - dice_coef: 0.7982 - binary_accuracy: 0.9997 - val_loss: -0.7626 - val_dice_coef: 0.7648 - val_binary_accuracy: 0.9997 - lr: 2.3530e-05
# Epoch 19/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7782 - dice_coef: 0.7863 - binary_accuracy: 0.9997
# Epoch 19: val_loss did not improve from -0.76306
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.6470857008243908e-05.
# 16/16 [==============================] - 17s 1s/step - loss: -0.7782 - dice_coef: 0.7863 - binary_accuracy: 0.9997 - val_loss: -0.7495 - val_dice_coef: 0.7517 - val_binary_accuracy: 0.9997 - lr: 2.3530e-05
# Epoch 20/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7862 - dice_coef: 0.7875 - binary_accuracy: 0.9997
# Epoch 20: val_loss did not improve from -0.76306
# 16/16 [==============================] - 17s 1s/step - loss: -0.7862 - dice_coef: 0.7875 - binary_accuracy: 0.9997 - val_loss: -0.7568 - val_dice_coef: 0.7592 - val_binary_accuracy: 0.9997 - lr: 1.6471e-05
# Epoch 21/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7879 - dice_coef: 0.7423 - binary_accuracy: 0.9997
# Epoch 21: val_loss did not improve from -0.76306
# 16/16 [==============================] - 17s 1s/step - loss: -0.7879 - dice_coef: 0.7423 - binary_accuracy: 0.9997 - val_loss: -0.7563 - val_dice_coef: 0.7587 - val_binary_accuracy: 0.9997 - lr: 1.6471e-05
# Epoch 22/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7954 - dice_coef: 0.7495 - binary_accuracy: 0.9997
# Epoch 22: val_loss improved from -0.76306 to -0.76318, saving model to checkpoint-022-0.765.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7954 - dice_coef: 0.7495 - binary_accuracy: 0.9997 - val_loss: -0.7632 - val_dice_coef: 0.7654 - val_binary_accuracy: 0.9997 - lr: 1.6471e-05
# Epoch 23/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7887 - dice_coef: 0.7431 - binary_accuracy: 0.9997
# Epoch 23: val_loss did not improve from -0.76318
# 16/16 [==============================] - 17s 1s/step - loss: -0.7887 - dice_coef: 0.7431 - binary_accuracy: 0.9997 - val_loss: -0.7620 - val_dice_coef: 0.7642 - val_binary_accuracy: 0.9997 - lr: 1.6471e-05
# Epoch 24/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7982 - dice_coef: 0.8036 - binary_accuracy: 0.9997
# Epoch 24: val_loss did not improve from -0.76318
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.1529599396453704e-05.
# 16/16 [==============================] - 17s 1s/step - loss: -0.7982 - dice_coef: 0.8036 - binary_accuracy: 0.9997 - val_loss: -0.7614 - val_dice_coef: 0.7637 - val_binary_accuracy: 0.9997 - lr: 1.6471e-05
# Epoch 25/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7924 - dice_coef: 0.7904 - binary_accuracy: 0.9997
# Epoch 25: val_loss did not improve from -0.76318
# 16/16 [==============================] - 17s 1s/step - loss: -0.7924 - dice_coef: 0.7904 - binary_accuracy: 0.9997 - val_loss: -0.7625 - val_dice_coef: 0.7648 - val_binary_accuracy: 0.9997 - lr: 1.1530e-05
# Epoch 26/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7976 - dice_coef: 0.7510 - binary_accuracy: 0.9997
# Epoch 26: val_loss improved from -0.76318 to -0.76557, saving model to checkpoint-026-0.768.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7976 - dice_coef: 0.7510 - binary_accuracy: 0.9997 - val_loss: -0.7656 - val_dice_coef: 0.7678 - val_binary_accuracy: 0.9997 - lr: 1.1530e-05
# Epoch 27/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7922 - dice_coef: 0.7750 - binary_accuracy: 0.9997
# Epoch 27: val_loss improved from -0.76557 to -0.76640, saving model to checkpoint-027-0.768.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.7922 - dice_coef: 0.7750 - binary_accuracy: 0.9997 - val_loss: -0.7664 - val_dice_coef: 0.7685 - val_binary_accuracy: 0.9997 - lr: 1.1530e-05
# Epoch 28/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7980 - dice_coef: 0.8064 - binary_accuracy: 0.9997
# Epoch 28: val_loss did not improve from -0.76640
# 16/16 [==============================] - 17s 1s/step - loss: -0.7980 - dice_coef: 0.8064 - binary_accuracy: 0.9997 - val_loss: -0.7637 - val_dice_coef: 0.7659 - val_binary_accuracy: 0.9997 - lr: 1.1530e-05
# Epoch 29/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7992 - dice_coef: 0.7589 - binary_accuracy: 0.9997
# Epoch 29: val_loss did not improve from -0.76640
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 8.070719832176109e-06.
# 16/16 [==============================] - 17s 1s/step - loss: -0.7992 - dice_coef: 0.7589 - binary_accuracy: 0.9997 - val_loss: -0.7644 - val_dice_coef: 0.7666 - val_binary_accuracy: 0.9997 - lr: 1.1530e-05
# Epoch 30/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8014 - dice_coef: 0.7562 - binary_accuracy: 0.9997
# Epoch 30: val_loss did not improve from -0.76640
# 16/16 [==============================] - 17s 1s/step - loss: -0.8014 - dice_coef: 0.7562 - binary_accuracy: 0.9997 - val_loss: -0.7656 - val_dice_coef: 0.7678 - val_binary_accuracy: 0.9997 - lr: 8.0707e-06
# Epoch 31/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8020 - dice_coef: 0.7578 - binary_accuracy: 0.9997
# Epoch 31: val_loss did not improve from -0.76640
# 16/16 [==============================] - 17s 1s/step - loss: -0.8020 - dice_coef: 0.7578 - binary_accuracy: 0.9997 - val_loss: -0.7662 - val_dice_coef: 0.7684 - val_binary_accuracy: 0.9997 - lr: 8.0707e-06
# Epoch 32/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8060 - dice_coef: 0.8117 - binary_accuracy: 0.9997
# Epoch 32: val_loss improved from -0.76640 to -0.76679, saving model to checkpoint-032-0.769.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8060 - dice_coef: 0.8117 - binary_accuracy: 0.9997 - val_loss: -0.7668 - val_dice_coef: 0.7689 - val_binary_accuracy: 0.9997 - lr: 8.0707e-06
# Epoch 33/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8024 - dice_coef: 0.7612 - binary_accuracy: 0.9997
# Epoch 33: val_loss did not improve from -0.76679
# 16/16 [==============================] - 17s 1s/step - loss: -0.8024 - dice_coef: 0.7612 - binary_accuracy: 0.9997 - val_loss: -0.7653 - val_dice_coef: 0.7675 - val_binary_accuracy: 0.9997 - lr: 8.0707e-06
# Epoch 34/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8006 - dice_coef: 0.7825 - binary_accuracy: 0.9997
# Epoch 34: val_loss did not improve from -0.76679
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.6495036915293895e-06.
# 16/16 [==============================] - 17s 1s/step - loss: -0.8006 - dice_coef: 0.7825 - binary_accuracy: 0.9997 - val_loss: -0.7639 - val_dice_coef: 0.7661 - val_binary_accuracy: 0.9997 - lr: 8.0707e-06
# Epoch 35/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8065 - dice_coef: 0.8176 - binary_accuracy: 0.9997
# Epoch 35: val_loss did not improve from -0.76679
# 16/16 [==============================] - 17s 1s/step - loss: -0.8065 - dice_coef: 0.8176 - binary_accuracy: 0.9997 - val_loss: -0.7660 - val_dice_coef: 0.7682 - val_binary_accuracy: 0.9997 - lr: 5.6495e-06
# Epoch 36/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8058 - dice_coef: 0.8157 - binary_accuracy: 0.9997
# Epoch 36: val_loss did not improve from -0.76679
# 16/16 [==============================] - 17s 1s/step - loss: -0.8058 - dice_coef: 0.8157 - binary_accuracy: 0.9997 - val_loss: -0.7661 - val_dice_coef: 0.7683 - val_binary_accuracy: 0.9997 - lr: 5.6495e-06
# Epoch 37/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8089 - dice_coef: 0.7618 - binary_accuracy: 0.9997
# Epoch 37: val_loss did not improve from -0.76679
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.954652584070573e-06.
# 16/16 [==============================] - 17s 1s/step - loss: -0.8089 - dice_coef: 0.7618 - binary_accuracy: 0.9997 - val_loss: -0.7661 - val_dice_coef: 0.7683 - val_binary_accuracy: 0.9997 - lr: 5.6495e-06
# Epoch 38/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7961 - dice_coef: 0.7501 - binary_accuracy: 0.9997
# Epoch 38: val_loss did not improve from -0.76679
# 16/16 [==============================] - 17s 1s/step - loss: -0.7961 - dice_coef: 0.7501 - binary_accuracy: 0.9997 - val_loss: -0.7666 - val_dice_coef: 0.7687 - val_binary_accuracy: 0.9997 - lr: 3.9547e-06
# Epoch 39/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8022 - dice_coef: 0.8095 - binary_accuracy: 0.9997
# Epoch 39: val_loss did not improve from -0.76679
# 16/16 [==============================] - 17s 1s/step - loss: -0.8022 - dice_coef: 0.8095 - binary_accuracy: 0.9997 - val_loss: -0.7655 - val_dice_coef: 0.7677 - val_binary_accuracy: 0.9997 - lr: 3.9547e-06
# Epoch 40/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8067 - dice_coef: 0.7887 - binary_accuracy: 0.9997
# Epoch 40: val_loss did not improve from -0.76679
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.7682568088494007e-06.
# 16/16 [==============================] - 17s 1s/step - loss: -0.8067 - dice_coef: 0.7887 - binary_accuracy: 0.9997 - val_loss: -0.7666 - val_dice_coef: 0.7688 - val_binary_accuracy: 0.9997 - lr: 3.9547e-06
# Epoch 41/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8067 - dice_coef: 0.8068 - binary_accuracy: 0.9997
# Epoch 41: val_loss did not improve from -0.76679
# 16/16 [==============================] - 17s 1s/step - loss: -0.8067 - dice_coef: 0.8068 - binary_accuracy: 0.9997 - val_loss: -0.7660 - val_dice_coef: 0.7682 - val_binary_accuracy: 0.9997 - lr: 2.7683e-06
# Epoch 42/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8084 - dice_coef: 0.8138 - binary_accuracy: 0.9997
# Epoch 42: val_loss did not improve from -0.76679
# 16/16 [==============================] - 17s 1s/step - loss: -0.8084 - dice_coef: 0.8138 - binary_accuracy: 0.9997 - val_loss: -0.7665 - val_dice_coef: 0.7687 - val_binary_accuracy: 0.9997 - lr: 2.7683e-06
# Epoch 43/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8002 - dice_coef: 0.7551 - binary_accuracy: 0.9997
# Epoch 43: val_loss improved from -0.76679 to -0.76696, saving model to checkpoint-043-0.769.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8002 - dice_coef: 0.7551 - binary_accuracy: 0.9997 - val_loss: -0.7670 - val_dice_coef: 0.7691 - val_binary_accuracy: 0.9997 - lr: 2.7683e-06
# Epoch 44/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8110 - dice_coef: 0.8129 - binary_accuracy: 0.9997
# Epoch 44: val_loss improved from -0.76696 to -0.76752, saving model to checkpoint-044-0.770.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8110 - dice_coef: 0.8129 - binary_accuracy: 0.9997 - val_loss: -0.7675 - val_dice_coef: 0.7697 - val_binary_accuracy: 0.9997 - lr: 2.7683e-06
# Epoch 45/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8039 - dice_coef: 0.8113 - binary_accuracy: 0.9997
# Epoch 45: val_loss did not improve from -0.76752
# 16/16 [==============================] - 17s 1s/step - loss: -0.8039 - dice_coef: 0.8113 - binary_accuracy: 0.9997 - val_loss: -0.7665 - val_dice_coef: 0.7687 - val_binary_accuracy: 0.9997 - lr: 2.7683e-06
# Epoch 46/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8054 - dice_coef: 0.7596 - binary_accuracy: 0.9997
# Epoch 46: val_loss did not improve from -0.76752
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.937779734362266e-06.
# 16/16 [==============================] - 17s 1s/step - loss: -0.8054 - dice_coef: 0.7596 - binary_accuracy: 0.9997 - val_loss: -0.7666 - val_dice_coef: 0.7688 - val_binary_accuracy: 0.9997 - lr: 2.7683e-06
# Epoch 47/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8066 - dice_coef: 0.8159 - binary_accuracy: 0.9997
# Epoch 47: val_loss did not improve from -0.76752
# 16/16 [==============================] - 17s 1s/step - loss: -0.8066 - dice_coef: 0.8159 - binary_accuracy: 0.9997 - val_loss: -0.7668 - val_dice_coef: 0.7690 - val_binary_accuracy: 0.9997 - lr: 1.9378e-06
# Epoch 48/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8073 - dice_coef: 0.7601 - binary_accuracy: 0.9997
# Epoch 48: val_loss did not improve from -0.76752
# 16/16 [==============================] - 17s 1s/step - loss: -0.8073 - dice_coef: 0.7601 - binary_accuracy: 0.9997 - val_loss: -0.7667 - val_dice_coef: 0.7689 - val_binary_accuracy: 0.9997 - lr: 1.9378e-06
# Epoch 49/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8031 - dice_coef: 0.8116 - binary_accuracy: 0.9997
# Epoch 49: val_loss did not improve from -0.76752
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.356445750388957e-06.
# 16/16 [==============================] - 17s 1s/step - loss: -0.8031 - dice_coef: 0.8116 - binary_accuracy: 0.9997 - val_loss: -0.7673 - val_dice_coef: 0.7694 - val_binary_accuracy: 0.9997 - lr: 1.9378e-06
# Epoch 50/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8002 - dice_coef: 0.7538 - binary_accuracy: 0.9997
# Epoch 50: val_loss did not improve from -0.76752
# 16/16 [==============================] - 17s 1s/step - loss: -0.8002 - dice_coef: 0.7538 - binary_accuracy: 0.9997 - val_loss: -0.7674 - val_dice_coef: 0.7696 - val_binary_accuracy: 0.9997 - lr: 1.3564e-06
# Epoch 51/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8068 - dice_coef: 0.8069 - binary_accuracy: 0.9997
# Epoch 51: val_loss did not improve from -0.76752
# 16/16 [==============================] - 17s 1s/step - loss: -0.8068 - dice_coef: 0.8069 - binary_accuracy: 0.9997 - val_loss: -0.7674 - val_dice_coef: 0.7695 - val_binary_accuracy: 0.9997 - lr: 1.3564e-06
# Epoch 52/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8032 - dice_coef: 0.8119 - binary_accuracy: 0.9997
# Epoch 52: val_loss did not improve from -0.76752
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1e-06.
# 16/16 [==============================] - 17s 1s/step - loss: -0.8032 - dice_coef: 0.8119 - binary_accuracy: 0.9997 - val_loss: -0.7674 - val_dice_coef: 0.7695 - val_binary_accuracy: 0.9997 - lr: 1.3564e-06
# Epoch 53/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8051 - dice_coef: 0.8139 - binary_accuracy: 0.9997
# Epoch 53: val_loss improved from -0.76752 to -0.76803, saving model to checkpoint-053-0.770.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8051 - dice_coef: 0.8139 - binary_accuracy: 0.9997 - val_loss: -0.7680 - val_dice_coef: 0.7702 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 54/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8045 - dice_coef: 0.8126 - binary_accuracy: 0.9997
# Epoch 54: val_loss improved from -0.76803 to -0.76804, saving model to checkpoint-054-0.770.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8045 - dice_coef: 0.8126 - binary_accuracy: 0.9997 - val_loss: -0.7680 - val_dice_coef: 0.7702 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 55/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8140 - dice_coef: 0.8175 - binary_accuracy: 0.9997
# Epoch 55: val_loss improved from -0.76804 to -0.76811, saving model to checkpoint-055-0.770.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8140 - dice_coef: 0.8175 - binary_accuracy: 0.9997 - val_loss: -0.7681 - val_dice_coef: 0.7702 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 56/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7994 - dice_coef: 0.7818 - binary_accuracy: 0.9997
# Epoch 56: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.7994 - dice_coef: 0.7818 - binary_accuracy: 0.9997 - val_loss: -0.7678 - val_dice_coef: 0.7699 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 57/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8066 - dice_coef: 0.7610 - binary_accuracy: 0.9997
# Epoch 57: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8066 - dice_coef: 0.7610 - binary_accuracy: 0.9997 - val_loss: -0.7675 - val_dice_coef: 0.7696 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 58/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7996 - dice_coef: 0.8096 - binary_accuracy: 0.9997
# Epoch 58: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.7996 - dice_coef: 0.8096 - binary_accuracy: 0.9997 - val_loss: -0.7677 - val_dice_coef: 0.7698 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 59/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8017 - dice_coef: 0.7556 - binary_accuracy: 0.9997
# Epoch 59: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8017 - dice_coef: 0.7556 - binary_accuracy: 0.9997 - val_loss: -0.7674 - val_dice_coef: 0.7695 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 60/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8003 - dice_coef: 0.8067 - binary_accuracy: 0.9997
# Epoch 60: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8003 - dice_coef: 0.8067 - binary_accuracy: 0.9997 - val_loss: -0.7677 - val_dice_coef: 0.7698 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 61/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8058 - dice_coef: 0.8145 - binary_accuracy: 0.9997
# Epoch 61: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8058 - dice_coef: 0.8145 - binary_accuracy: 0.9997 - val_loss: -0.7674 - val_dice_coef: 0.7695 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 62/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8116 - dice_coef: 0.8129 - binary_accuracy: 0.9997
# Epoch 62: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8116 - dice_coef: 0.8129 - binary_accuracy: 0.9997 - val_loss: -0.7674 - val_dice_coef: 0.7696 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 63/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8027 - dice_coef: 0.7562 - binary_accuracy: 0.9997
# Epoch 63: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8027 - dice_coef: 0.7562 - binary_accuracy: 0.9997 - val_loss: -0.7676 - val_dice_coef: 0.7698 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 64/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8041 - dice_coef: 0.8083 - binary_accuracy: 0.9997
# Epoch 64: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8041 - dice_coef: 0.8083 - binary_accuracy: 0.9997 - val_loss: -0.7678 - val_dice_coef: 0.7699 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 65/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8065 - dice_coef: 0.8066 - binary_accuracy: 0.9997
# Epoch 65: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8065 - dice_coef: 0.8066 - binary_accuracy: 0.9997 - val_loss: -0.7678 - val_dice_coef: 0.7699 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 66/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8090 - dice_coef: 0.8143 - binary_accuracy: 0.9997
# Epoch 66: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8090 - dice_coef: 0.8143 - binary_accuracy: 0.9997 - val_loss: -0.7677 - val_dice_coef: 0.7699 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 67/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8055 - dice_coef: 0.7593 - binary_accuracy: 0.9997
# Epoch 67: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8055 - dice_coef: 0.7593 - binary_accuracy: 0.9997 - val_loss: -0.7678 - val_dice_coef: 0.7700 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 68/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7931 - dice_coef: 0.7467 - binary_accuracy: 0.9997
# Epoch 68: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.7931 - dice_coef: 0.7467 - binary_accuracy: 0.9997 - val_loss: -0.7680 - val_dice_coef: 0.7701 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 69/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8012 - dice_coef: 0.8093 - binary_accuracy: 0.9997
# Epoch 69: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8012 - dice_coef: 0.8093 - binary_accuracy: 0.9997 - val_loss: -0.7676 - val_dice_coef: 0.7697 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 70/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8118 - dice_coef: 0.7934 - binary_accuracy: 0.9997
# Epoch 70: val_loss did not improve from -0.76811
# 16/16 [==============================] - 17s 1s/step - loss: -0.8118 - dice_coef: 0.7934 - binary_accuracy: 0.9997 - val_loss: -0.7680 - val_dice_coef: 0.7702 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 71/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8074 - dice_coef: 0.7604 - binary_accuracy: 0.9997
# Epoch 71: val_loss improved from -0.76811 to -0.76820, saving model to checkpoint-071-0.770.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8074 - dice_coef: 0.7604 - binary_accuracy: 0.9997 - val_loss: -0.7682 - val_dice_coef: 0.7703 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 72/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8084 - dice_coef: 0.8070 - binary_accuracy: 0.9997
# Epoch 72: val_loss did not improve from -0.76820
# 16/16 [==============================] - 17s 1s/step - loss: -0.8084 - dice_coef: 0.8070 - binary_accuracy: 0.9997 - val_loss: -0.7680 - val_dice_coef: 0.7702 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 73/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8058 - dice_coef: 0.7588 - binary_accuracy: 0.9997
# Epoch 73: val_loss did not improve from -0.76820
# 16/16 [==============================] - 17s 1s/step - loss: -0.8058 - dice_coef: 0.7588 - binary_accuracy: 0.9997 - val_loss: -0.7670 - val_dice_coef: 0.7692 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 74/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8057 - dice_coef: 0.8136 - binary_accuracy: 0.9997
# Epoch 74: val_loss did not improve from -0.76820
# 16/16 [==============================] - 17s 1s/step - loss: -0.8057 - dice_coef: 0.8136 - binary_accuracy: 0.9997 - val_loss: -0.7680 - val_dice_coef: 0.7701 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 75/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8107 - dice_coef: 0.8205 - binary_accuracy: 0.9997
# Epoch 75: val_loss improved from -0.76820 to -0.76852, saving model to checkpoint-075-0.771.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8107 - dice_coef: 0.8205 - binary_accuracy: 0.9997 - val_loss: -0.7685 - val_dice_coef: 0.7707 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 76/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8053 - dice_coef: 0.7647 - binary_accuracy: 0.9997
# Epoch 76: val_loss improved from -0.76852 to -0.76868, saving model to checkpoint-076-0.771.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8053 - dice_coef: 0.7647 - binary_accuracy: 0.9997 - val_loss: -0.7687 - val_dice_coef: 0.7708 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 77/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8051 - dice_coef: 0.7873 - binary_accuracy: 0.9997
# Epoch 77: val_loss did not improve from -0.76868
# 16/16 [==============================] - 17s 1s/step - loss: -0.8051 - dice_coef: 0.7873 - binary_accuracy: 0.9997 - val_loss: -0.7686 - val_dice_coef: 0.7707 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 78/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8069 - dice_coef: 0.8159 - binary_accuracy: 0.9997
# Epoch 78: val_loss improved from -0.76868 to -0.76874, saving model to checkpoint-078-0.771.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8069 - dice_coef: 0.8159 - binary_accuracy: 0.9997 - val_loss: -0.7687 - val_dice_coef: 0.7709 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 79/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8044 - dice_coef: 0.8102 - binary_accuracy: 0.9997
# Epoch 79: val_loss improved from -0.76874 to -0.76880, saving model to checkpoint-079-0.771.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8044 - dice_coef: 0.8102 - binary_accuracy: 0.9997 - val_loss: -0.7688 - val_dice_coef: 0.7709 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 80/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8137 - dice_coef: 0.8210 - binary_accuracy: 0.9997
# Epoch 80: val_loss did not improve from -0.76880
# 16/16 [==============================] - 17s 1s/step - loss: -0.8137 - dice_coef: 0.8210 - binary_accuracy: 0.9997 - val_loss: -0.7687 - val_dice_coef: 0.7709 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 81/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8045 - dice_coef: 0.7580 - binary_accuracy: 0.9997
# Epoch 81: val_loss did not improve from -0.76880
# 16/16 [==============================] - 17s 1s/step - loss: -0.8045 - dice_coef: 0.7580 - binary_accuracy: 0.9997 - val_loss: -0.7685 - val_dice_coef: 0.7707 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 82/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7943 - dice_coef: 0.7487 - binary_accuracy: 0.9997
# Epoch 82: val_loss did not improve from -0.76880
# 16/16 [==============================] - 17s 1s/step - loss: -0.7943 - dice_coef: 0.7487 - binary_accuracy: 0.9997 - val_loss: -0.7685 - val_dice_coef: 0.7706 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 83/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8077 - dice_coef: 0.8078 - binary_accuracy: 0.9997
# Epoch 83: val_loss did not improve from -0.76880
# 16/16 [==============================] - 17s 1s/step - loss: -0.8077 - dice_coef: 0.8078 - binary_accuracy: 0.9997 - val_loss: -0.7681 - val_dice_coef: 0.7702 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 84/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8046 - dice_coef: 0.7592 - binary_accuracy: 0.9997
# Epoch 84: val_loss did not improve from -0.76880
# 16/16 [==============================] - 17s 1s/step - loss: -0.8046 - dice_coef: 0.7592 - binary_accuracy: 0.9997 - val_loss: -0.7679 - val_dice_coef: 0.7700 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 85/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8001 - dice_coef: 0.7825 - binary_accuracy: 0.9997
# Epoch 85: val_loss did not improve from -0.76880
# 16/16 [==============================] - 17s 1s/step - loss: -0.8001 - dice_coef: 0.7825 - binary_accuracy: 0.9997 - val_loss: -0.7687 - val_dice_coef: 0.7708 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 86/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8112 - dice_coef: 0.8168 - binary_accuracy: 0.9997
# Epoch 86: val_loss improved from -0.76880 to -0.76895, saving model to checkpoint-086-0.771.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8112 - dice_coef: 0.8168 - binary_accuracy: 0.9997 - val_loss: -0.7690 - val_dice_coef: 0.7711 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 87/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8113 - dice_coef: 0.8175 - binary_accuracy: 0.9997
# Epoch 87: val_loss did not improve from -0.76895
# 16/16 [==============================] - 17s 1s/step - loss: -0.8113 - dice_coef: 0.8175 - binary_accuracy: 0.9997 - val_loss: -0.7688 - val_dice_coef: 0.7709 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 88/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8074 - dice_coef: 0.7610 - binary_accuracy: 0.9997
# Epoch 88: val_loss did not improve from -0.76895
# 16/16 [==============================] - 17s 1s/step - loss: -0.8074 - dice_coef: 0.7610 - binary_accuracy: 0.9997 - val_loss: -0.7687 - val_dice_coef: 0.7708 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 89/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8050 - dice_coef: 0.7588 - binary_accuracy: 0.9997
# Epoch 89: val_loss did not improve from -0.76895
# 16/16 [==============================] - 17s 1s/step - loss: -0.8050 - dice_coef: 0.7588 - binary_accuracy: 0.9997 - val_loss: -0.7687 - val_dice_coef: 0.7708 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 90/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8094 - dice_coef: 0.8150 - binary_accuracy: 0.9997
# Epoch 90: val_loss did not improve from -0.76895
# 16/16 [==============================] - 17s 1s/step - loss: -0.8094 - dice_coef: 0.8150 - binary_accuracy: 0.9997 - val_loss: -0.7687 - val_dice_coef: 0.7708 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 91/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8107 - dice_coef: 0.8173 - binary_accuracy: 0.9997
# Epoch 91: val_loss improved from -0.76895 to -0.76901, saving model to checkpoint-091-0.771.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8107 - dice_coef: 0.8173 - binary_accuracy: 0.9997 - val_loss: -0.7690 - val_dice_coef: 0.7712 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 92/100
# 16/16 [==============================] - ETA: 0s - loss: -0.7980 - dice_coef: 0.8002 - binary_accuracy: 0.9997
# Epoch 92: val_loss did not improve from -0.76901
# 16/16 [==============================] - 17s 1s/step - loss: -0.7980 - dice_coef: 0.8002 - binary_accuracy: 0.9997 - val_loss: -0.7687 - val_dice_coef: 0.7708 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 93/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8082 - dice_coef: 0.8090 - binary_accuracy: 0.9997
# Epoch 93: val_loss did not improve from -0.76901
# 16/16 [==============================] - 17s 1s/step - loss: -0.8082 - dice_coef: 0.8090 - binary_accuracy: 0.9997 - val_loss: -0.7683 - val_dice_coef: 0.7705 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 94/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8054 - dice_coef: 0.8113 - binary_accuracy: 0.9997
# Epoch 94: val_loss did not improve from -0.76901
# 16/16 [==============================] - 17s 1s/step - loss: -0.8054 - dice_coef: 0.8113 - binary_accuracy: 0.9997 - val_loss: -0.7689 - val_dice_coef: 0.7711 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 95/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8076 - dice_coef: 0.8130 - binary_accuracy: 0.9997
# Epoch 95: val_loss did not improve from -0.76901
# 16/16 [==============================] - 17s 1s/step - loss: -0.8076 - dice_coef: 0.8130 - binary_accuracy: 0.9997 - val_loss: -0.7686 - val_dice_coef: 0.7708 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 96/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8061 - dice_coef: 0.8083 - binary_accuracy: 0.9997
# Epoch 96: val_loss improved from -0.76901 to -0.76916, saving model to checkpoint-096-0.771.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8061 - dice_coef: 0.8083 - binary_accuracy: 0.9997 - val_loss: -0.7692 - val_dice_coef: 0.7713 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 97/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8058 - dice_coef: 0.8140 - binary_accuracy: 0.9997
# Epoch 97: val_loss improved from -0.76916 to -0.77001, saving model to checkpoint-097-0.772.hdf5
# 16/16 [==============================] - 17s 1s/step - loss: -0.8058 - dice_coef: 0.8140 - binary_accuracy: 0.9997 - val_loss: -0.7700 - val_dice_coef: 0.7721 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 98/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8100 - dice_coef: 0.7629 - binary_accuracy: 0.9997
# Epoch 98: val_loss did not improve from -0.77001
# 16/16 [==============================] - 17s 1s/step - loss: -0.8100 - dice_coef: 0.7629 - binary_accuracy: 0.9997 - val_loss: -0.7698 - val_dice_coef: 0.7719 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 99/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8110 - dice_coef: 0.7644 - binary_accuracy: 0.9997
# Epoch 99: val_loss did not improve from -0.77001
# 16/16 [==============================] - 17s 1s/step - loss: -0.8110 - dice_coef: 0.7644 - binary_accuracy: 0.9997 - val_loss: -0.7696 - val_dice_coef: 0.7717 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06
# Epoch 100/100
# 16/16 [==============================] - ETA: 0s - loss: -0.8049 - dice_coef: 0.7675 - binary_accuracy: 0.9997
# Epoch 100: val_loss did not improve from -0.77001
# 16/16 [==============================] - 17s 1s/step - loss: -0.8049 - dice_coef: 0.7675 - binary_accuracy: 0.9997 - val_loss: -0.7694 - val_dice_coef: 0.7715 - val_binary_accuracy: 0.9997 - lr: 1.0000e-06

# %%
plt.figure(figsize=(20,6))
for i, met in enumerate(['dice_coef', 'loss']):
  plt.subplot(1,2,i+1)
  plt.plot(history.history[met], color="b")
  plt.plot(history.history["val_"+met], color="g")
  plt.title('Model '+met.capitalize())
  plt.xlabel('epochs')
  plt.ylabel(met)
  plt.legend(['train', 'val'])

# %%
import pickle
with open('LC_UNet_trainHistory', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

# %%
model.save("UNet.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.evaluate(testX, testY)
# Out:
# 2/2 [==============================] - 51s 25s/step - loss: -0.7867 - dice_coef: 0.7875 - binary_accuracy: 0.9997
# [-0.786710798740387, 0.7875498533248901, 0.999713122844696]

# %%
model2 = unet(input_size=(512,512,1))
model2.load_weights("checkpoint-071-0.775.hdf5")

model2.compile(optimizer=Adam(learning_rate=2e-4),
                loss=[dice_coef_loss],
                metrics = [dice_coef, 'binary_accuracy'])

model2.evaluate(testX, testY)
# Out:
# 2/2 [==============================] - 2s 513ms/step - loss: -0.7878 - dice_coef: 0.7887 - binary_accuracy: 0.9997
# [-0.7877946496009827, 0.7886589765548706, 0.9997154474258423]

# %%
model2.save("UNet_best_Model_checkpoint.h5")

# %%
j = 1
for i in range(30, min(80, len(testX))):  # Adjust the loop range
    test = np.squeeze(testX)[i]
    t_p = model2.predict(np.reshape(test, (1, 512, 512, 1)))

    plt.figure(figsize=(20, 300))
    plt.subplot(50, 3, j)
    plt.imshow(np.squeeze(test), cmap="bone")
    plt.subplot(50, 3, j + 1)
    plt.imshow(np.squeeze(t_p), cmap="gray")
    plt.subplot(50, 3, j + 2)
    plt.imshow(cv2.addWeighted(np.squeeze(test), .5, np.squeeze(t_p), .5, 0), cmap="gray")
    j += 3
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !mkdir -p /content/gdrive/MyDrive/archive/Training_Logs

# %%
# !cp UNet.h5 /content/gdrive/MyDrive/archive/Training_Logs/UNet.h5
# !cp LC_UNet_trainHistory /content/gdrive/MyDrive/archive/Training_Logs/UNet_trainHistory

# %%
# !cp UNet_best_Model_checkpoint.h5 /content/gdrive/MyDrive/archive/Training_Logs/UNet_best_Model_checkpoint.h5
